# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/opeyemiamodu/desktop/Udemy Py/UNZIP_ME_FOR_NOTEBOOKS_Ver2/05-Seaborn/application_record.csv')

# %%
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   438557 non-null  int64
#  1   CODE_GENDER          438557 non-null  object
#  2   FLAG_OWN_CAR         438557 non-null  object
#  3   FLAG_OWN_REALTY      438557 non-null  object
#  4   CNT_CHILDREN         438557 non-null  int64
#  5   AMT_INCOME_TOTAL     438557 non-null  float64
#  6   NAME_INCOME_TYPE     438557 non-null  object
#  7   NAME_EDUCATION_TYPE  438557 non-null  object
#  8   NAME_FAMILY_STATUS   438557 non-null  object
#  9   NAME_HOUSING_TYPE    438557 non-null  object
#  10  DAYS_BIRTH           438557 non-null  int64
#  11  DAYS_EMPLOYED        438557 non-null  int64
#  12  FLAG_MOBIL           438557 non-null  int64
#  13  FLAG_WORK_PHONE      438557 non-null  int64
#  14  FLAG_PHONE           438557 non-null  int64
# ...

# %%
df['DAYS_EMPLOYED']
# Out:
# 0          -4542
# 1          -4542
# 2          -1134
# 3          -3051
# 4          -3051
#            ...
# 438552    365243
# 438553     -3007
# 438554      -372
# 438555    365243
# 438556     -1201
# Name: DAYS_EMPLOYED, Length: 438557, dtype: int64

# %%
df['DAYS_BIRTH'] = df['DAYS_BIRTH'] * -1

# %%
df['DAYS_BIRTH']
# Out:
# 0         12005
# 1         12005
# 2         21474
# 3         19110
# 4         19110
#           ...
# 438552    22717
# 438553    15939
# 438554     8169
# 438555    21673
# 438556    18858
# Name: DAYS_BIRTH, Length: 438557, dtype: int64

# %%
employed = df[df['DAYS_EMPLOYED'] < 0]

# %%
employed
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438547  6839917           F            N               Y             0
# 438548  6839936           M            Y               Y             1
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
employed['DAYS_EMPLOYED'].notnull()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 438547    True
# 438548    True
# 438553    True
# 438554    True
# 438556    True
# Name: DAYS_EMPLOYED, Length: 363228, dtype: bool

# %%
employed['DAYS_EMPLOYED'] = employed['DAYS_EMPLOYED'] * -1
# Out:
# <ipython-input-61-445029c0fcca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   employed['DAYS_EMPLOYED'] = employed['DAYS_EMPLOYED'] * -1

# %%
employed['DAYS_EMPLOYED']
# Out:
# 0         4542
# 1         4542
# 2         1134
# 3         3051
# 4         3051
#           ...
# 438547    2704
# 438548    2095
# 438553    3007
# 438554     372
# 438556    1201
# Name: DAYS_EMPLOYED, Length: 363228, dtype: int64

# %%
employed['DAYS_BIRTH']
# Out:
# 0         12005
# 1         12005
# 2         21474
# 3         19110
# 4         19110
#           ...
# 438547    10966
# 438548    12569
# 438553    15939
# 438554     8169
# 438556    18858
# Name: DAYS_BIRTH, Length: 363228, dtype: int64

# %%
plt.figure(figsize =(8, 6), dpi = 120 )

sns.scatterplot( data = employed, y = 'DAYS_EMPLOYED', x = 'DAYS_BIRTH', alpha = 0.01 )
plt.show()

# %%
employed['Age in Years'] = round(employed['DAYS_BIRTH']/365)
# Out:
# <ipython-input-81-e0524984a059>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   employed['Age in Years'] = round(employed['DAYS_BIRTH']/365)

# %%
employed['Age in Years']
# Out:
# 0         33.0
# 1         33.0
# 2         59.0
# 3         52.0
# 4         52.0
#           ...
# 438547    30.0
# 438548    34.0
# 438553    44.0
# 438554    22.0
# 438556    52.0
# Name: Age in Years, Length: 363228, dtype: float64

# %%
employed['Age in Years'].count()
# Out:
# 363228

# %%
df['Age in Years'] = round(-1 * df['DAYS_BIRTH']/365)

# %%
df['Age in Years'] = df['Age in Years'] * -1

# %%
df['Age in Years']
# Out:
# 0         33.0
# 1         33.0
# 2         59.0
# 3         52.0
# 4         52.0
#           ...
# 438552    62.0
# 438553    44.0
# 438554    22.0
# 438555    59.0
# 438556    52.0
# Name: Age in Years, Length: 438557, dtype: float64

# %%
plt.figure(figsize = (8, 6))
sns.histplot(data = df, x = 'Age in Years', bins = 25, color = 'pink', edgecolor = 'black')
plt.show()

# %%
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
df['NAME_FAMILY_STATUS']
# Out:
# 0               Civil marriage
# 1               Civil marriage
# 2                      Married
# 3         Single / not married
# 4         Single / not married
#                   ...
# 438552               Separated
# 438553    Single / not married
# 438554    Single / not married
# 438555                 Married
# 438556                 Married
# Name: NAME_FAMILY_STATUS, Length: 438557, dtype: object

# %%
df['AMT_INCOME_TOTAL'].max()
# Out:
# 6750000.0

# %%
df['AMT_INCOME_TOTAL'].min()
# Out:
# 26100.0

# %%
round(df['AMT_INCOME_TOTAL'].mean())
# Out:
# 187524

# %%
income = df['AMT_INCOME_TOTAL'] > round(df['AMT_INCOME_TOTAL'].mean())

# %%
df['income'] = 'income'

# %%
df = df.drop('income', axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   438557 non-null  int64
#  1   CODE_GENDER          438557 non-null  object
#  2   FLAG_OWN_CAR         438557 non-null  object
#  3   FLAG_OWN_REALTY      438557 non-null  object
#  4   CNT_CHILDREN         438557 non-null  int64
#  5   AMT_INCOME_TOTAL     438557 non-null  float64
#  6   NAME_INCOME_TYPE     438557 non-null  object
#  7   NAME_EDUCATION_TYPE  438557 non-null  object
#  8   NAME_FAMILY_STATUS   438557 non-null  object
#  9   NAME_HOUSING_TYPE    438557 non-null  object
#  10  DAYS_BIRTH           438557 non-null  int64
#  11  DAYS_EMPLOYED        438557 non-null  int64
#  12  FLAG_MOBIL           438557 non-null  int64
#  13  FLAG_WORK_PHONE      438557 non-null  int64
#  14  FLAG_PHONE           438557 non-null  int64
# ...

# %%
bottom_half_income = df.nsmallest(int(len(df)/2), columns = 'AMT_INCOME_TOTAL')

# %%
bottom_half_income
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 273113  6093713           F            N               N             0
# 436891  6093712           F            N               N             0
# 43817   5126174           F            N               N             0
# 43818   5126175           F            N               N             0
# 43819   5995345           F            N               N             0
# ...         ...         ...          ...             ...           ...
# 322007  6273675           M            Y               Y             0
# 322008  6273677           M            Y               Y             0
# 322009  6273679           M            Y               Y             0
# 322010  6273680           M            Y               Y             0
# 322011  6273681           M            Y               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
plt.figure(figsize = (12, 5), dpi = 120)
sns.boxplot(data = bottom_half_income, y = 'AMT_INCOME_TOTAL', x = 'NAME_FAMILY_STATUS', hue = 'FLAG_OWN_REALTY')
plt.legend(bbox_to_anchor = (1.20, 0.5), title = 'FLAG_OWN_REALTY' )
plt.show()

# %%
df.corr()
# Out:
#                         ID  CNT_CHILDREN  AMT_INCOME_TOTAL  DAYS_BIRTH  \
# ID                1.000000     -0.005178          0.011179    0.004994
# CNT_CHILDREN     -0.005178      1.000000          0.019177   -0.349088
# AMT_INCOME_TOTAL  0.011179      0.019177          1.000000   -0.053775
# DAYS_BIRTH        0.004994     -0.349088         -0.053775    1.000000
# DAYS_EMPLOYED    -0.002467     -0.241535         -0.141291    0.617908
# FLAG_MOBIL             NaN           NaN               NaN         NaN
# FLAG_WORK_PHONE  -0.023319      0.038418         -0.033635   -0.171829
# FLAG_PHONE       -0.018992     -0.038266          0.004444    0.037984
# FLAG_EMAIL        0.032875      0.028457          0.112139   -0.096752
# CNT_FAM_MEMBERS  -0.001862      0.884781          0.011454   -0.306179
# Age in Years      0.004947     -0.349058         -0.053785    0.999686
#
#                   DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  \
# ...

# %%
df.drop('FLAG_MOBIL', axis = 1).corr()
# Out:
#                         ID  CNT_CHILDREN  AMT_INCOME_TOTAL  DAYS_BIRTH  \
# ID                1.000000     -0.005178          0.011179    0.004994
# CNT_CHILDREN     -0.005178      1.000000          0.019177   -0.349088
# AMT_INCOME_TOTAL  0.011179      0.019177          1.000000   -0.053775
# DAYS_BIRTH        0.004994     -0.349088         -0.053775    1.000000
# DAYS_EMPLOYED    -0.002467     -0.241535         -0.141291    0.617908
# FLAG_WORK_PHONE  -0.023319      0.038418         -0.033635   -0.171829
# FLAG_PHONE       -0.018992     -0.038266          0.004444    0.037984
# FLAG_EMAIL        0.032875      0.028457          0.112139   -0.096752
# CNT_FAM_MEMBERS  -0.001862      0.884781          0.011454   -0.306179
# Age in Years      0.004947     -0.349058         -0.053785    0.999686
#
#                   DAYS_EMPLOYED  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  \
# ID                    -0.002467        -0.023319   -0.018992    0.032875
# ...

# %%
plt.figure(figsize = (10, 5), dpi = 100)
sns.heatmap(df.drop('FLAG_MOBIL', axis = 1).corr(), lw = 0.5, annot = True, cmap = 'viridis')
plt.show()
